# %%
Name = input("enter your name")
matric = float(input("enter your matric percentage"))

if matric >= 70:
    inter = float(input("enter your intermidiat percentage"))
    if inter >= 70:
        entry_test = float(input("enter your entry test percentage"))
        if entry_test >= 80:
            print(f"{Name} you are qualified")
        else:
            print(f"{Name} you are not qualified because your entry test marks is too low")
    else:
        print(f"{Name} you are not qualified because your intermidiat marks is too low")
else:
    print(f"{Name} you are not qualified because your matric marks is too low")
# Out:
# enter your name zeeshan khan
# enter your matric percentage 75
# enter your intermidiat percentage 45
# zeeshan khan you are not qualified because your intermidiat marks is too low

# %%
sentence = "  python is an amazing programming language.  "

# %%
print (sentence.title())
print (sentence.starts_with("python"))
print (sentence.count("python"))
print (len(sentence))
# Out:
#   Python Is An Amazing Programming Language.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 print (sentence.title())
# ----> 2 print (sentence.starts_with("python"))
#       3 print (sentence.count("python"))
#       4 print (len(sentence))
#
# AttributeError: 'str' object has no attribute 'starts_with'
