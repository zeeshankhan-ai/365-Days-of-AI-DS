# %%
open("file15.txt").read()
# Out:
# 'Zeeshan you are great scientist'

# %%
with open("another.txt", "w") as file:
    file.write("yeah im great ")
    file.write("everyone know")

   open("another.txt", "r")
    content = file.read()
    
    print(content)
# Out:
#   File <string>:5
#     open("another.txt", "r")
#                             ^
# IndentationError: unindent does not match any outer indentation level
