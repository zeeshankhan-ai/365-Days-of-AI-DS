# %%
name = input("enter your name")
age  = int(input("enter your age "))

if age >= 60:
   print(f"{name} YOu are senior citizen")
else:
   print(f"{name} YOu are not senior citizen")
# Out:
# enter your name zeeshan khan
# enter your age  22
# zeeshan khan YOu are not senior citizen

# %%
temp = float(input("enter today temprature"))

if temp >= 35:
    print("its a hot day")
else:
    print("its a normal day")
# Out:
# enter today temprature 22
# its a normal day

# %%
name = input("enter your name ")
math = int(float(input("enter your math marks")))
eng = int(float(input("enter your English marks")))
che = int(float(input("enter your chemistry marks")))
phy = int(float(input("enter your physics marks")))
total = math + eng + che + phy

if total >= 200:
     print(f"{name} you are pass Total marks {total}")
else:
     print(f"{name} you are pass Total marks {total}")
# Out:
# enter your name  zeeshan khan
# enter your math marks 90
# enter your English marks 60
# enter your chemistry marks 75
# enter your physics marks 70
# zeeshan khan you are pass Total marks 295
