# %%
class User:
    def __init__(self, first_name, last_name, username, email):
        self.first_name = first_name
        self.last_name = last_name
        self.username = username
        self.email = email
        self.login_attempts = 0 
        
    def increment_login_attempts(self):
        self.login_attempts += 1
        print(" Login attempt incremented...")

    def reset_login_attempts(self):
        self.login_attempts = 0
        print(" Login attempts have been reset to 0.")


user1 = User("Zeeshan", "Khan", "ZeeshanKhanAI", "zeeshan@example.com")

print(f"Current Login Attempts: {user1.login_attempts}\n")

user1.increment_login_attempts()
user1.increment_login_attempts()
user1.increment_login_attempts()

print(f" Login Attempts After Increments: {user1.login_attempts}\n")


user1.reset_login_attempts()

print(f" Login Attempts After Reset: {user1.login_attempts}")
# Out:
# Current Login Attempts: 0
#
#  Login attempt incremented...
#  Login attempt incremented...
#  Login attempt incremented...
#  Login Attempts After Increments: 3
#
#  Login attempts have been reset to 0.
#  Login Attempts After Reset: 0

# %%
class User:
    def __init__(self, first_name, last_name, username, email):
        self.first_name = first_name
        self.last_name = last_name
        self.username = username
        self.email = email
        self.login_attempts = 0 

    def increment_login_attempts(self):
        self.login_attempts += 1


class Admin(User):
    def __init__(self, first_name, last_name, username, email):
        super().__init__(first_name, last_name, username, email)
        
        self.privileges = ["can add post", "can delete post", "can ban user"]

    def show_privileges(self):
        print(f"\n Admin '{self.username}' has the following privileges:")
        for privilege in self.privileges:
            print(f"  {privilege}")


admin1 = Admin("Zeeshan", "Khan", "ZeeshanAdminAI", "admin.zeeshan@example.com")

print(f"Full Name: {admin1.first_name} {admin1.last_name}")
print(f"Email: {admin1.email}")

admin1.show_privileges()
# Out:
# Full Name: Zeeshan Khan
# Email: admin.zeeshan@example.com
#
#  Admin 'ZeeshanAdminAI' has the following privileges:
#   can add post
#   can delete post
#   can ban user
