# %%
f_name = input("Enter your first name")
l_name = input("Enter your last name")
course_name = input("Enter your course name")
batch_number = input("Enter your batch number")
# Out:
# Enter your first name zeeshan
# Enter your last name khan
# Enter your course name accp
# Enter your batch number 08f

# %%
print(f"I am {f_name} {l_name} and I am studying {course_name} program in batch {batch_number}")
# Out:
# I am zeeshan khan and I am studying accp program in batch 08f

# %%
p_name = input("Enter product name")
price = float(input("Enter product price"))
quantity = int(input("Enter product price"))
# Out:
# Enter product name brush
# Enter product price 234.43
# Enter product price 2

# %%
total = price*quantity

# %%
f"""your orderis {p_name}
quantity {quantity}
price {price}
total bil {total}"""
# Out:
# 'your orderis brush\nquantity 2\nprice 234.43\ntotal bil 468.86'

# %%
name = input("enter your name")
age  = int(input ("enter your age "))
if age >= 18:
      print (f"{name} u can drive")
else:
        print (f"{name} u cannot drive")
# Out:
# enter your name zeeshan khan
# enter your age  22
# zeeshan khan  u can drive

# %%
if age <= 18:
      print (f"{name} u can drive")
else:
        print (f"{name} u cannot drive")
# Out:
# zeeshan khan  u cannot drive
