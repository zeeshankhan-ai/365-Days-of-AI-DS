# %%
x = 250
y = 250

# %%
x is y
# Out:
# True

# %%
z = "zeeshan"
c = "yasir"

# %%
z is c
# Out:
# False

# %%
id(x)
# Out:
# 140721408361160

# %%
id(y)
# Out:
# 140721408361160

# %%
name = input("your name ")
age = int(float(input()))
# Out:
# your name  zeeshan
#  22

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
wallet =  300

# %%
wallet =  500

# %%
wallet
# Out:
# 500

# %%
hobby = input("Enter your hobby here")
duration = int(float(input("Enter your duration")))
# Out:
# Enter your hobby here boxing
# Enter your duration 2

# %%
f'my hobby is $hobby and my duration is $duration'
# Out:
# 'my hobby is $hobby and my duration is $duration'
