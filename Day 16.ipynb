# %%
try:
    age = int(input("Meharbani karke apni age likhein: "))

    print(f"Zabardast! Aapki age {age} saal hai. ")

except ValueError:
    print(" Galti! Meharbani karke sirf numbers me apni age likhein.")
# Out:
# Meharbani karke apni age likhein:  zeeshan
#  Galti! Meharbani karke sirf numbers me apni age likhein.
